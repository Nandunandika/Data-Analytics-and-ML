# %%
#Load the dataset
import pandas as pd
covid=pd.read_csv('owid-covid-data.csv')

# %%
#Dimensons
covid.shape
# Out:
# (19708, 32)

# %%
#To display last 5 Rows
covid.tail()
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 19703      NaN  International  2020-02-28          705          0
# 19704      NaN  International  2020-02-29          705          0
# 19705      NaN  International  2020-03-01          705          0
# 19706      NaN  International  2020-03-02          705          0
# 19707      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 19703             4           0                      NaN
# 19704             6           2                      NaN
# 19705             6           0                      NaN
# 19706             6           0                      NaN
# 19707             7           1                      NaN
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 19703                    NaN                       NaN  ...            NaN
# 19704                    NaN                       NaN  ...            NaN
# 19705                    NaN                       NaN  ...            NaN
# 19706                    NaN                       NaN  ...            NaN
# 19707                    NaN                       NaN  ...            NaN
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cvd_death_rate  \
# 19703            NaN             NaN              NaN             NaN
# 19704            NaN             NaN              NaN             NaN
# 19705            NaN             NaN              NaN             NaN
# 19706            NaN             NaN              NaN             NaN
# 19707            NaN             NaN              NaN             NaN
#
#        diabetes_prevalence  female_smokers male_smokers  \
# 19703                  NaN             NaN          NaN
# 19704                  NaN             NaN          NaN
# 19705                  NaN             NaN          NaN
# 19706                  NaN             NaN          NaN
# 19707                  NaN             NaN          NaN
#
#        handwashing_facilities  hospital_beds_per_100k
# 19703                     NaN                     NaN
# 19704                     NaN                     NaN
# 19705                     NaN                     NaN
# 19706                     NaN                     NaN
# 19707                     NaN                     NaN
#
# [5 rows x 32 columns]

# %%
#To display 1st 5 Rows
covid.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                       0.0  ...         13.085          7.452
# 1                       0.0  ...         13.085          7.452
# 2                       0.0  ...         13.085          7.452
# 3                       0.0  ...         13.085          7.452
# 4                       0.0  ...         13.085          7.452
#
#    gdp_per_capita  extreme_poverty  cvd_death_rate  diabetes_prevalence  \
# 0       35973.781              NaN             NaN                11.62
# 1       35973.781              NaN             NaN                11.62
# 2       35973.781              NaN             NaN                11.62
# 3       35973.781              NaN             NaN                11.62
# 4       35973.781              NaN             NaN                11.62
#
#    female_smokers male_smokers  handwashing_facilities  hospital_beds_per_100k
# 0             NaN          NaN                     NaN                     NaN
# 1             NaN          NaN                     NaN                     NaN
# 2             NaN          NaN                     NaN                     NaN
# 3             NaN          NaN                     NaN                     NaN
# 4             NaN          NaN                     NaN                     NaN
#
# [5 rows x 32 columns]

# %%
#To display all the columns present in the data set
covid.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
#To find the unique values in the series
covid["location"].value_counts()
# Out:
# Iceland           147
# Belarus           147
# United States     147
# Japan             147
# Brazil            147
#                  ...
# Yemen              46
# Western Sahara     30
# Tajikistan         25
# Comoros            24
# Lesotho            11
# Name: location, Length: 212, dtype: int64

# %%
#For Description
covid.describe(include='O')
# Out:
#        iso_code location        date      tests_units
# count     19644    19708       19708             6384
# unique      211      212         147                5
# top         HRV  Iceland  2020-05-15  tests performed
# freq        147      147         211             2520

# %%
#To Check Null Values Present in the data
covid.isna().any()
# Out:
# iso_code                            True
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million             True
# new_cases_per_million               True
# total_deaths_per_million            True
# new_deaths_per_million              True
# total_tests                         True
# new_tests                           True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_units                         True
# stringency_index                    True
# population                          True
# population_density                  True
# median_age                          True
# aged_65_older                       True
# aged_70_older                       True
# gdp_per_capita                      True
# extreme_poverty                     True
# cvd_death_rate                      True
# diabetes_prevalence                 True
# female_smokers                      True
# male_smokers                        True
# handwashing_facilities              True
# hospital_beds_per_100k              True
# dtype: bool

# %%
#Total Null Values
covid.isna().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# new_cases                              0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14421
# new_tests                          15009
# total_tests_per_thousand           14421
# new_tests_per_thousand             15009
# new_tests_smoothed                 13923
# new_tests_smoothed_per_thousand    13923
# tests_units                        13324
# stringency_index                    4490
# population                            64
# population_density                   862
# median_age                          1767
# aged_65_older                       2007
# aged_70_older                       1857
# gdp_per_capita                      2010
# extreme_poverty                     7968
# cvd_death_rate                      1841
# diabetes_prevalence                 1191
# female_smokers                      5121
# male_smokers                        5277
# handwashing_facilities             11942
# hospital_beds_per_100k              3205
# dtype: int64

# %%
#Cases only in India
India_case=covid[covid["location"]=="India"]
India_case
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8470      IND    India  2019-12-31            0          0             0
# 8471      IND    India  2020-01-01            0          0             0
# 8472      IND    India  2020-01-02            0          0             0
# 8473      IND    India  2020-01-03            0          0             0
# 8474      IND    India  2020-01-04            0          0             0
# ...       ...      ...         ...          ...        ...           ...
# 8611      IND    India  2020-05-21       112359       5609          3435
# 8612      IND    India  2020-05-22       118447       6088          3583
# 8613      IND    India  2020-05-23       125101       6654          3720
# 8614      IND    India  2020-05-24       131868       6767          3867
# 8615      IND    India  2020-05-25       138845       6977          4021
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8470           0                    0.000                  0.000
# 8471           0                    0.000                  0.000
# 8472           0                    0.000                  0.000
# 8473           0                    0.000                  0.000
# 8474           0                    0.000                  0.000
# ...          ...                      ...                    ...
# 8611         132                   81.419                  4.064
# 8612         148                   85.831                  4.412
# 8613         137                   90.653                  4.822
# 8614         147                   95.556                  4.904
# 8615         154                  100.612                  5.056
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 8470                     0.000  ...          5.989          3.414
# 8471                     0.000  ...          5.989          3.414
# 8472                     0.000  ...          5.989          3.414
# 8473                     0.000  ...          5.989          3.414
# 8474                     0.000  ...          5.989          3.414
# ...                        ...  ...            ...            ...
# 8611                     2.489  ...          5.989          3.414
# 8612                     2.596  ...          5.989          3.414
# 8613                     2.696  ...          5.989          3.414
# 8614                     2.802  ...          5.989          3.414
# 8615                     2.914  ...          5.989          3.414
#
#       gdp_per_capita  extreme_poverty  cvd_death_rate  diabetes_prevalence  \
# 8470        6426.674             21.2          282.28                10.39
# 8471        6426.674             21.2          282.28                10.39
# 8472        6426.674             21.2          282.28                10.39
# 8473        6426.674             21.2          282.28                10.39
# 8474        6426.674             21.2          282.28                10.39
# ...              ...              ...             ...                  ...
# 8611        6426.674             21.2          282.28                10.39
# 8612        6426.674             21.2          282.28                10.39
# 8613        6426.674             21.2          282.28                10.39
# 8614        6426.674             21.2          282.28                10.39
# 8615        6426.674             21.2          282.28                10.39
#
#       female_smokers male_smokers  handwashing_facilities  \
# 8470             1.9         20.6                   59.55
# 8471             1.9         20.6                   59.55
# 8472             1.9         20.6                   59.55
# 8473             1.9         20.6                   59.55
# 8474             1.9         20.6                   59.55
# ...              ...          ...                     ...
# 8611             1.9         20.6                   59.55
# 8612             1.9         20.6                   59.55
# 8613             1.9         20.6                   59.55
# 8614             1.9         20.6                   59.55
# 8615             1.9         20.6                   59.55
#
#       hospital_beds_per_100k
# 8470                    0.53
# 8471                    0.53
# 8472                    0.53
# 8473                    0.53
# 8474                    0.53
# ...                      ...
# 8611                    0.53
# 8612                    0.53
# 8613                    0.53
# 8614                    0.53
# 8615                    0.53
#
# [146 rows x 32 columns]

# %%
India_case.head()
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8470      IND    India  2019-12-31            0          0             0
# 8471      IND    India  2020-01-01            0          0             0
# 8472      IND    India  2020-01-02            0          0             0
# 8473      IND    India  2020-01-03            0          0             0
# 8474      IND    India  2020-01-04            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8470           0                      0.0                    0.0
# 8471           0                      0.0                    0.0
# 8472           0                      0.0                    0.0
# 8473           0                      0.0                    0.0
# 8474           0                      0.0                    0.0
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 8470                       0.0  ...          5.989          3.414
# 8471                       0.0  ...          5.989          3.414
# 8472                       0.0  ...          5.989          3.414
# 8473                       0.0  ...          5.989          3.414
# 8474                       0.0  ...          5.989          3.414
#
#       gdp_per_capita  extreme_poverty  cvd_death_rate  diabetes_prevalence  \
# 8470        6426.674             21.2          282.28                10.39
# 8471        6426.674             21.2          282.28                10.39
# 8472        6426.674             21.2          282.28                10.39
# 8473        6426.674             21.2          282.28                10.39
# 8474        6426.674             21.2          282.28                10.39
#
#       female_smokers male_smokers  handwashing_facilities  \
# 8470             1.9         20.6                   59.55
# 8471             1.9         20.6                   59.55
# 8472             1.9         20.6                   59.55
# 8473             1.9         20.6                   59.55
# 8474             1.9         20.6                   59.55
#
#       hospital_beds_per_100k
# 8470                    0.53
# 8471                    0.53
# 8472                    0.53
# 8473                    0.53
# 8474                    0.53
#
# [5 rows x 32 columns]

# %%
India_case.tail()
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8611      IND    India  2020-05-21       112359       5609          3435
# 8612      IND    India  2020-05-22       118447       6088          3583
# 8613      IND    India  2020-05-23       125101       6654          3720
# 8614      IND    India  2020-05-24       131868       6767          3867
# 8615      IND    India  2020-05-25       138845       6977          4021
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8611         132                   81.419                  4.064
# 8612         148                   85.831                  4.412
# 8613         137                   90.653                  4.822
# 8614         147                   95.556                  4.904
# 8615         154                  100.612                  5.056
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 8611                     2.489  ...          5.989          3.414
# 8612                     2.596  ...          5.989          3.414
# 8613                     2.696  ...          5.989          3.414
# 8614                     2.802  ...          5.989          3.414
# 8615                     2.914  ...          5.989          3.414
#
#       gdp_per_capita  extreme_poverty  cvd_death_rate  diabetes_prevalence  \
# 8611        6426.674             21.2          282.28                10.39
# 8612        6426.674             21.2          282.28                10.39
# 8613        6426.674             21.2          282.28                10.39
# 8614        6426.674             21.2          282.28                10.39
# 8615        6426.674             21.2          282.28                10.39
#
#       female_smokers male_smokers  handwashing_facilities  \
# 8611             1.9         20.6                   59.55
# 8612             1.9         20.6                   59.55
# 8613             1.9         20.6                   59.55
# 8614             1.9         20.6                   59.55
# 8615             1.9         20.6                   59.55
#
#       hospital_beds_per_100k
# 8611                    0.53
# 8612                    0.53
# 8613                    0.53
# 8614                    0.53
# 8615                    0.53
#
# [5 rows x 32 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#Total cases per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=India_case)
plt.show()

# %%
#Making a dataframe for last 5 days
India_last_5_days=India_case.tail()

# %%
#Total cases in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=India_last_5_days)
plt.show()

# %%
#Total tests per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=India_case)
plt.show()

# %%
#Understanding cases of India, China , Japan and United States
india_japan_china_us=covid[(covid["location"] =="India") | (covid["location"] =="China") | (covid["location"]=="Japan")|(covid["location"]=="United States")]

# %%
#Plotting growth of cases across China, India and Japan
sns.set(rc={'figure.figsize':(25,20)})
sns.barplot(x="location",y="total_cases",data=india_japan_china_us,hue="date")
plt.show()

# %%
#Getting latest data
last_day_cases=covid[covid["date"]=="2020-05-25"]
last_day_cases
# Out:
#        iso_code      location        date  total_cases  new_cases  \
# 63          ABW         Aruba  2020-05-25          101          0
# 200         AFG   Afghanistan  2020-05-25        10582        584
# 265         AGO        Angola  2020-05-25           69          9
# 325         AIA      Anguilla  2020-05-25            3          0
# 403         ALB       Albania  2020-05-25          998          9
# ...         ...           ...         ...          ...        ...
# 19253       YEM         Yemen  2020-05-25          222         10
# 19362       ZAF  South Africa  2020-05-25        22583       1240
# 19430       ZMB        Zambia  2020-05-25          920          0
# 19496       ZWE      Zimbabwe  2020-05-25           56          0
# 19643  OWID_WRL         World  2020-05-25      5371700      94633
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 63                3           0                  945.994
# 200             218           2                  271.833
# 265               4           1                    2.099
# 325               0           0                  199.973
# 403              32           1                  346.793
# ...             ...         ...                      ...
# 19253            42           3                    7.443
# 19362           429          22                  380.771
# 19430             7           0                   50.044
# 19496             4           0                    3.768
# 19643        344815        2737                  689.139
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 63                     0.000                    28.099  ...         13.085
# 200                   15.002                     5.600  ...          2.581
# 265                    0.274                     0.122  ...          2.405
# 325                    0.000                     0.000  ...            NaN
# 403                    3.127                    11.120  ...         13.188
# ...                      ...                       ...  ...            ...
# 19253                  0.335                     1.408  ...          2.922
# 19362                 20.908                     7.233  ...          5.344
# 19430                  0.000                     0.381  ...          2.480
# 19496                  0.000                     0.269  ...          2.822
# 19643                 12.141                    44.237  ...          8.696
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cvd_death_rate  \
# 63             7.452       35973.781              NaN             NaN
# 200            1.337        1803.987              NaN         597.029
# 265            1.362        5819.495              NaN         276.045
# 325              NaN             NaN              NaN             NaN
# 403            8.643       11803.431              1.1         304.195
# ...              ...             ...              ...             ...
# 19253          1.583        1479.147             18.8         495.003
# 19362          3.053       12294.876             18.9         200.380
# 19430          1.542        3689.251             57.5         234.499
# 19496          1.882        1899.775             21.4         307.846
# 19643          5.355       15469.207             10.0         233.070
#
#        diabetes_prevalence  female_smokers male_smokers  \
# 63                   11.62             NaN          NaN
# 200                   9.59             NaN          NaN
# 265                   3.94             NaN          NaN
# 325                    NaN             NaN          NaN
# 403                  10.08           7.100       51.200
# ...                    ...             ...          ...
# 19253                 5.35           7.600       29.200
# 19362                 5.52           8.100       33.200
# 19430                 3.94           3.100       24.700
# 19496                 1.82           1.600       30.700
# 19643                 8.51           6.434       34.635
#
#        handwashing_facilities  hospital_beds_per_100k
# 63                        NaN                     NaN
# 200                    37.746                   0.500
# 265                    26.664                     NaN
# 325                       NaN                     NaN
# 403                       NaN                   2.890
# ...                       ...                     ...
# 19253                  49.542                   0.700
# 19362                  43.993                   2.320
# 19430                  13.938                   2.000
# 19496                  36.791                   1.700
# 19643                  60.130                   2.705
#
# [209 rows x 32 columns]

# %%
#Sorting data w.r.t total_cases
max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country
# Out:
#        iso_code                         location        date  total_cases  \
# 19643  OWID_WRL                            World  2020-05-25      5371700
# 18589       USA                    United States  2020-05-25      1643238
# 2683        BRA                           Brazil  2020-05-25       363211
# 15732       RUS                           Russia  2020-05-25       344481
# 6669        GBR                   United Kingdom  2020-05-25       259559
# ...         ...                              ...         ...          ...
# 18927       VGB           British Virgin Islands  2020-05-25            8
# 1662        BES  Bonaire Sint Eustatius and Saba  2020-05-25            7
# 5603        ESH                   Western Sahara  2020-05-25            6
# 325         AIA                         Anguilla  2020-05-25            3
# 11203       LSO                          Lesotho  2020-05-25            2
#
#        new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 19643      94633        344815        2737                  689.139
# 18589      20568         97720         633                 4964.426
# 2683       15813         22666         653                 1708.751
# 15732       8599          3541         153                 2360.519
# 6669        2405         36793         118                 3823.454
# ...          ...           ...         ...                      ...
# 18927          0             1           0                  264.577
# 1662           1             0           0                  266.962
# 5603           0             0           0                   10.045
# 325            0             0           0                  199.973
# 11203          0             0           0                    0.934
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 19643                 12.141                    44.237  ...          8.696
# 18589                 62.138                   295.224  ...         15.413
# 2683                  74.393                   106.634  ...          8.552
# 15732                 58.924                    24.264  ...         14.178
# 6669                  35.427                   541.982  ...         18.517
# ...                      ...                       ...  ...            ...
# 18927                  0.000                    33.072  ...            NaN
# 1662                  38.137                     0.000  ...            NaN
# 5603                   0.000                     0.000  ...            NaN
# 325                    0.000                     0.000  ...            NaN
# 11203                  0.000                     0.000  ...          4.506
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cvd_death_rate  \
# 19643          5.355       15469.207             10.0         233.070
# 18589          9.732       54225.446              1.2         151.089
# 2683           5.060       14103.452              3.4         177.961
# 15732          9.393       24765.954              0.1         431.297
# 6669          12.527       39753.244              0.2         122.137
# ...              ...             ...              ...             ...
# 18927            NaN             NaN              NaN             NaN
# 1662             NaN             NaN              NaN             NaN
# 5603           1.380             NaN              NaN             NaN
# 325              NaN             NaN              NaN             NaN
# 11203          2.647        2851.153             59.6         405.126
#
#        diabetes_prevalence  female_smokers male_smokers  \
# 19643                 8.51           6.434       34.635
# 18589                10.79          19.100       24.600
# 2683                  8.11          10.100       17.900
# 15732                 6.18          23.400       58.300
# 6669                  4.28          20.000       24.700
# ...                    ...             ...          ...
# 18927                13.67             NaN          NaN
# 1662                   NaN             NaN          NaN
# 5603                   NaN             NaN          NaN
# 325                    NaN             NaN          NaN
# 11203                 3.94           0.400       53.900
#
#        handwashing_facilities  hospital_beds_per_100k
# 19643                  60.130                   2.705
# 18589                     NaN                   2.770
# 2683                      NaN                   2.200
# 15732                     NaN                   8.050
# 6669                      NaN                   2.540
# ...                       ...                     ...
# 18927                     NaN                     NaN
# 1662                      NaN                     NaN
# 5603                      NaN                     NaN
# 325                       NaN                     NaN
# 11203                   2.117                     NaN
#
# [209 rows x 32 columns]

# %%
#Top 5 countries with maximum cases
max_cases_country[1:6]
# Out:
#       iso_code        location        date  total_cases  new_cases  \
# 18589      USA   United States  2020-05-25      1643238      20568
# 2683       BRA          Brazil  2020-05-25       363211      15813
# 15732      RUS          Russia  2020-05-25       344481       8599
# 6669       GBR  United Kingdom  2020-05-25       259559       2405
# 9494       ITA           Italy  2020-05-25       229858        531
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 18589         97720         633                 4964.426
# 2683          22666         653                 1708.751
# 15732          3541         153                 2360.519
# 6669          36793         118                 3823.454
# 9494          32785          50                 3801.704
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 18589                 62.138                   295.224  ...         15.413
# 2683                  74.393                   106.634  ...          8.552
# 15732                 58.924                    24.264  ...         14.178
# 6669                  35.427                   541.982  ...         18.517
# 9494                   8.782                   542.243  ...         23.021
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cvd_death_rate  \
# 18589          9.732       54225.446              1.2         151.089
# 2683           5.060       14103.452              3.4         177.961
# 15732          9.393       24765.954              0.1         431.297
# 6669          12.527       39753.244              0.2         122.137
# 9494          16.240       35220.084              2.0         113.151
#
#        diabetes_prevalence  female_smokers male_smokers  \
# 18589                10.79            19.1         24.6
# 2683                  8.11            10.1         17.9
# 15732                 6.18            23.4         58.3
# 6669                  4.28            20.0         24.7
# 9494                  4.78            19.8         27.8
#
#        handwashing_facilities  hospital_beds_per_100k
# 18589                     NaN                    2.77
# 2683                      NaN                    2.20
# 15732                     NaN                    8.05
# 6669                      NaN                    2.54
# 9494                      NaN                    3.18
#
# [5 rows x 32 columns]

# %%
#Sorting data w.r.t total_cases
min_cases_country=last_day_cases.sort_values(by="total_cases",ascending=True)
min_cases_country
# Out:
#        iso_code                         location        date  total_cases  \
# 11203       LSO                          Lesotho  2020-05-25            2
# 325         AIA                         Anguilla  2020-05-25            3
# 5603        ESH                   Western Sahara  2020-05-25            6
# 1662        BES  Bonaire Sint Eustatius and Saba  2020-05-25            7
# 18927       VGB           British Virgin Islands  2020-05-25            8
# ...         ...                              ...         ...          ...
# 6669        GBR                   United Kingdom  2020-05-25       259559
# 15732       RUS                           Russia  2020-05-25       344481
# 2683        BRA                           Brazil  2020-05-25       363211
# 18589       USA                    United States  2020-05-25      1643238
# 19643  OWID_WRL                            World  2020-05-25      5371700
#
#        new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 11203          0             0           0                    0.934
# 325            0             0           0                  199.973
# 5603           0             0           0                   10.045
# 1662           1             0           0                  266.962
# 18927          0             1           0                  264.577
# ...          ...           ...         ...                      ...
# 6669        2405         36793         118                 3823.454
# 15732       8599          3541         153                 2360.519
# 2683       15813         22666         653                 1708.751
# 18589      20568         97720         633                 4964.426
# 19643      94633        344815        2737                  689.139
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 11203                  0.000                     0.000  ...          4.506
# 325                    0.000                     0.000  ...            NaN
# 5603                   0.000                     0.000  ...            NaN
# 1662                  38.137                     0.000  ...            NaN
# 18927                  0.000                    33.072  ...            NaN
# ...                      ...                       ...  ...            ...
# 6669                  35.427                   541.982  ...         18.517
# 15732                 58.924                    24.264  ...         14.178
# 2683                  74.393                   106.634  ...          8.552
# 18589                 62.138                   295.224  ...         15.413
# 19643                 12.141                    44.237  ...          8.696
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cvd_death_rate  \
# 11203          2.647        2851.153             59.6         405.126
# 325              NaN             NaN              NaN             NaN
# 5603           1.380             NaN              NaN             NaN
# 1662             NaN             NaN              NaN             NaN
# 18927            NaN             NaN              NaN             NaN
# ...              ...             ...              ...             ...
# 6669          12.527       39753.244              0.2         122.137
# 15732          9.393       24765.954              0.1         431.297
# 2683           5.060       14103.452              3.4         177.961
# 18589          9.732       54225.446              1.2         151.089
# 19643          5.355       15469.207             10.0         233.070
#
#        diabetes_prevalence  female_smokers male_smokers  \
# 11203                 3.94           0.400       53.900
# 325                    NaN             NaN          NaN
# 5603                   NaN             NaN          NaN
# 1662                   NaN             NaN          NaN
# 18927                13.67             NaN          NaN
# ...                    ...             ...          ...
# 6669                  4.28          20.000       24.700
# 15732                 6.18          23.400       58.300
# 2683                  8.11          10.100       17.900
# 18589                10.79          19.100       24.600
# 19643                 8.51           6.434       34.635
#
#        handwashing_facilities  hospital_beds_per_100k
# 11203                   2.117                     NaN
# 325                       NaN                     NaN
# 5603                      NaN                     NaN
# 1662                      NaN                     NaN
# 18927                     NaN                     NaN
# ...                       ...                     ...
# 6669                      NaN                   2.540
# 15732                     NaN                   8.050
# 2683                      NaN                   2.200
# 18589                     NaN                   2.770
# 19643                  60.130                   2.705
#
# [209 rows x 32 columns]

# %%
#Top 5 countries with manimum cases
min_cases_country[1:6]
# Out:
#       iso_code                         location        date  total_cases  \
# 325        AIA                         Anguilla  2020-05-25            3
# 5603       ESH                   Western Sahara  2020-05-25            6
# 1662       BES  Bonaire Sint Eustatius and Saba  2020-05-25            7
# 18927      VGB           British Virgin Islands  2020-05-25            8
# 14842      PNG                 Papua New Guinea  2020-05-25            8
#
#        new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 325            0             0           0                  199.973
# 5603           0             0           0                   10.045
# 1662           1             0           0                  266.962
# 18927          0             1           0                  264.577
# 14842          0             0           0                    0.894
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 325                    0.000                     0.000  ...            NaN
# 5603                   0.000                     0.000  ...            NaN
# 1662                  38.137                     0.000  ...            NaN
# 18927                  0.000                    33.072  ...            NaN
# 14842                  0.000                     0.000  ...          3.808
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cvd_death_rate  \
# 325              NaN             NaN              NaN             NaN
# 5603           1.380             NaN              NaN             NaN
# 1662             NaN             NaN              NaN             NaN
# 18927            NaN             NaN              NaN             NaN
# 14842          2.142        3823.194              NaN         561.494
#
#        diabetes_prevalence  female_smokers male_smokers  \
# 325                    NaN             NaN          NaN
# 5603                   NaN             NaN          NaN
# 1662                   NaN             NaN          NaN
# 18927                13.67             NaN          NaN
# 14842                17.65            23.5         48.8
#
#        handwashing_facilities  hospital_beds_per_100k
# 325                       NaN                     NaN
# 5603                      NaN                     NaN
# 1662                      NaN                     NaN
# 18927                     NaN                     NaN
# 14842                     NaN                     NaN
#
# [5 rows x 32 columns]

# %%
#Making bar-plot for countries with top cases
sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],hue="location")
plt.show()
